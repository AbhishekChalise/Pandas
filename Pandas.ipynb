# %%
import pandas as pd

dv = "C:/Users/abhis/Downloads/Demographics data.csv"

df = pd.read_csv(dv)

# %%
df
# Out:
#                         Country Name Country Code  \
# 0                             Africa          NaN
# 1                            Algeria          DZA
# 2                             Angola          AGO
# 3                           Botswana          BWA
# 4                       Burkina Faso          BFA
# 5                            Burundi          BDI
# 6                           Cameroon          CMR
# 7           Central African Republic          CAF
# 8                               Chad          TCD
# 9                            Comoros          COM
# 10  Democratic Republic of the Congo          COD
# 11                             Egypt          EGY
# 12                 Equatorial Guinea          EQG
# 13                           Eritrea         ERIT
# 14                          Eswatini          SWZ
# 15                          Ethiopia          ETH
# 16                             Gabon          GAB
# 17                            Gambia          GMB
# ...

# %%
len(df) # gives us only total number of rows
# Out:
# 51

# %%
df.shape
# Out:
# (51, 5)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birthrate (per 1,000 people)',
#        'Internet Users (Percentage)', 'Income Group'],
#       dtype='object')

# %%
df.head() # display top 5 rows
# Out:
#    Country Name Country Code  Birthrate (per 1,000 people)  \
# 0        Africa          NaN                           NaN
# 1       Algeria          DZA                          23.1
# 2        Angola          AGO                          35.7
# 3      Botswana          BWA                          22.8
# 4  Burkina Faso          BFA                          35.1
#
#    Internet Users (Percentage)         Income Group
# 0                          NaN                  NaN
# 1                         55.0  Lower-middle-income
# 2                         40.0  Lower-middle-income
# 3                         50.0  Upper-middle-income
# 4                         15.0           Low-income

# %%
df.tail() # bottom 5 rows
# Out:
#    Country Name Country Code  Birthrate (per 1,000 people)  \
# 46         Togo          TGO                          31.2
# 47      Tunisia          TUN                          21.0
# 48       Uganda          UGA                          37.0
# 49       Zambia          ZMB                          40.5
# 50     Zimbabwe          ZWE                          35.0
#
#     Internet Users (Percentage)         Income Group
# 46                         30.0  Lower-middle-income
# 47                         55.0  Lower-middle-income
# 48                         30.0           Low-income
# 49                         35.0  Lower-middle-income
# 50                         30.0  Lower-middle-income

# %%
df.head(10)
# Out:
#                Country Name Country Code  Birthrate (per 1,000 people)  \
# 0                    Africa          NaN                           NaN
# 1                   Algeria          DZA                          23.1
# 2                    Angola          AGO                          35.7
# 3                  Botswana          BWA                          22.8
# 4              Burkina Faso          BFA                          35.1
# 5                   Burundi          BDI                          34.5
# 6                  Cameroon          CMR                          30.7
# 7  Central African Republic          CAF                          34.5
# 8                      Chad          TCD                          36.0
# 9                   Comoros          COM                          28.3
#
#    Internet Users (Percentage)         Income Group
# 0                          NaN                  NaN
# 1                         55.0  Lower-middle-income
# ...

# %%
df.tail(10)
# Out:
#     Country Name Country Code  Birthrate (per 1,000 people)  \
# 41       Somalia          SOM                          32.7
# 42  South Africa          ZAF                          21.7
# 43   South Sudan          SSD                          35.1
# 44         Sudan          SDN                          35.0
# 45      Tanzania          TZA                          36.0
# 46          Togo          TGO                          31.2
# 47       Tunisia          TUN                          21.0
# 48        Uganda          UGA                          37.0
# 49        Zambia          ZMB                          40.5
# 50      Zimbabwe          ZWE                          35.0
#
#     Internet Users (Percentage)         Income Group
# 41                         10.0           Low-income
# 42                         65.0  Upper-middle-income
# 43                          5.0           Low-income
# 44                         20.0  Lower-middle-income
# ...

# %%
df.info() #Informations of the data sets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country Name                  51 non-null     object
#  1   Country Code                  50 non-null     object
#  2   Birthrate (per 1,000 people)  50 non-null     float64
#  3   Internet Users (Percentage)   50 non-null     float64
#  4   Income Group                  50 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 2.1+ KB

# %%
df.describe() # gives us numerical output not categorical
# Out:
#        Birthrate (per 1,000 people)  Internet Users (Percentage)
# count                     50.000000                    50.000000
# mean                      30.252000                    33.500000
# std                        6.615327                    19.672056
# min                       11.400000                     5.000000
# 25%                       26.100000                    20.000000
# 50%                       30.950000                    30.000000
# 75%                       35.100000                    48.750000
# max                       41.000000                    90.000000

# %%
df.transpose()
# Out:
#                                   0                    1   \
# Country Name                  Africa              Algeria
# Country Code                     NaN                  DZA
# Birthrate (per 1,000 people)     NaN                 23.1
# Internet Users (Percentage)      NaN                 55.0
# Income Group                     NaN  Lower-middle-income
#
#                                                2                    3   \
# Country Name                               Angola             Botswana
# Country Code                                  AGO                  BWA
# Birthrate (per 1,000 people)                 35.7                 22.8
# Internet Users (Percentage)                  40.0                 50.0
# Income Group                  Lower-middle-income  Upper-middle-income
#
#                                         4           5                    6   \
# Country Name                  Burkina Faso     Burundi             Cameroon
# ...

# %%
df[:]
# Out:
#                         Country Name Country Code  \
# 0                             Africa          NaN
# 1                            Algeria          DZA
# 2                             Angola          AGO
# 3                           Botswana          BWA
# 4                       Burkina Faso          BFA
# 5                            Burundi          BDI
# 6                           Cameroon          CMR
# 7           Central African Republic          CAF
# 8                               Chad          TCD
# 9                            Comoros          COM
# 10  Democratic Republic of the Congo          COD
# 11                             Egypt          EGY
# 12                 Equatorial Guinea          EQG
# 13                           Eritrea         ERIT
# 14                          Eswatini          SWZ
# 15                          Ethiopia          ETH
# 16                             Gabon          GAB
# 17                            Gambia          GMB
# ...

# %%
df[:10]
# Out:
#                Country Name Country Code  Birthrate (per 1,000 people)  \
# 0                    Africa          NaN                           NaN
# 1                   Algeria          DZA                          23.1
# 2                    Angola          AGO                          35.7
# 3                  Botswana          BWA                          22.8
# 4              Burkina Faso          BFA                          35.1
# 5                   Burundi          BDI                          34.5
# 6                  Cameroon          CMR                          30.7
# 7  Central African Republic          CAF                          34.5
# 8                      Chad          TCD                          36.0
# 9                   Comoros          COM                          28.3
#
#    Internet Users (Percentage)         Income Group
# 0                          NaN                  NaN
# 1                         55.0  Lower-middle-income
# ...

# %%
df[::-1]
# Out:
#                         Country Name Country Code  \
# 50                          Zimbabwe          ZWE
# 49                            Zambia          ZMB
# 48                            Uganda          UGA
# 47                           Tunisia          TUN
# 46                              Togo          TGO
# 45                          Tanzania          TZA
# 44                             Sudan          SDN
# 43                       South Sudan          SSD
# 42                      South Africa          ZAF
# 41                           Somalia          SOM
# 40                      Sierra Leone          SLE
# 39                        Seychelles          SYC
# 38                           Senegal          SEN
# 37             São Tomé and Príncipe          STP
# 36                            Rwanda          RWA
# 35                           Nigeria          NGA
# 34                             Niger          NER
# 33                           Namibia          NAM
# ...

# %%
df["Birthrate (per 1,000 people)"] # only print birth rate
# Out:
# 0      NaN
# 1     23.1
# 2     35.7
# 3     22.8
# 4     35.1
# 5     34.5
# 6     30.7
# 7     34.5
# 8     36.0
# 9     28.3
# 10    40.0
# 11    21.9
# 12    29.0
# 13    24.6
# 14    24.9
# 15    30.2
# 16    25.8
# 17    35.1
# 18    27.0
# 19    32.1
# 20    32.9
# 21    30.4
# 22    32.1
# 23    28.1
# 24    30.0
# 25    21.3
# 26    28.3
# 27    38.6
# 28    38.1
# 29    29.9
# 30    11.4
# 31    21.0
# 32    36.0
# 33    22.5
# 34    41.0
# 35    37.2
# 36    32.4
# 37    28.3
# 38    30.2
# 39    13.9
# 40    32.5
# 41    32.7
# 42    21.7
# 43    35.1
# 44    35.0
# 45    36.0
# 46    31.2
# 47    21.0
# 48    37.0
# 49    40.5
# 50    35.0
# Name: Birthrate (per 1,000 people), dtype: float64

# %%
df[['Country Name','Country Code']][1:3]
# Out:
#   Country Name Country Code
# 1      Algeria          DZA
# 2       Angola          AGO

# %%
df.rename(columns={'Birthrate (per 1,000 people)': 'Birthrate', 'Internet Users (Percentage)': 'Internet_Users','Income Group':'IncomeGroup'}, inplace=True)
df['mycalc'] = df['Birthrate'] * df['Internet_Users']

# %%
df.head()
# Out:
#    Country Name Country Code  Birthrate  Internet_Users          IncomeGroup  \
# 0        Africa          NaN        NaN             NaN                  NaN
# 1       Algeria          DZA       23.1            55.0  Lower-middle-income
# 2        Angola          AGO       35.7            40.0  Lower-middle-income
# 3      Botswana          BWA       22.8            50.0  Upper-middle-income
# 4  Burkina Faso          BFA       35.1            15.0           Low-income
#
#    mycalc
# 0     NaN
# 1  1270.5
# 2  1428.0
# 3  1140.0
# 4   526.5

# %%
df.tail()
# Out:
#    Country Name Country Code  Birthrate  Internet_Users         Income Group  \
# 46         Togo          TGO       31.2            30.0  Lower-middle-income
# 47      Tunisia          TUN       21.0            55.0  Lower-middle-income
# 48       Uganda          UGA       37.0            30.0           Low-income
# 49       Zambia          ZMB       40.5            35.0  Lower-middle-income
# 50     Zimbabwe          ZWE       35.0            30.0  Lower-middle-income
#
#     mycalc
# 46   936.0
# 47  1155.0
# 48  1110.0
# 49  1417.5
# 50  1050.0

# %%
df.drop('mycalc',axis = 1)
# Out:
#                         Country Name Country Code  Birthrate  Internet_Users  \
# 0                             Africa          NaN        NaN             NaN
# 1                            Algeria          DZA       23.1            55.0
# 2                             Angola          AGO       35.7            40.0
# 3                           Botswana          BWA       22.8            50.0
# 4                       Burkina Faso          BFA       35.1            15.0
# 5                            Burundi          BDI       34.5            10.0
# 6                           Cameroon          CMR       30.7            35.0
# 7           Central African Republic          CAF       34.5             5.0
# 8                               Chad          TCD       36.0            10.0
# 9                            Comoros          COM       28.3            30.0
# 10  Democratic Republic of the Congo          COD       40.0            10.0
# ...

# %%
df.columns[3:4]
# Out:
# Index(['Internet_Users'], dtype='object')

# %%
filter  =  df.Internet_Users<2
filter
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# Name: Internet_Users, dtype: bool

# %%
df[filter]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Birthrate, Internet_Users, Income Group, mycalc]
# Index: []

# %%
filter2  = df.Birthrate>40
filter2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# 50    False
# Name: Birthrate, dtype: bool

# %%
df[filter2]
# Out:
#    Country Name Country Code  Birthrate  Internet_Users         Income Group  \
# 34        Niger          NER       41.0            10.0           Low-income
# 49       Zambia          ZMB       40.5            35.0  Lower-middle-income
#
#     mycalc
# 34   410.0
# 49  1417.5

# %%
df[filter & filter2]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Birthrate, Internet_Users, Income Group, mycalc]
# Index: []

# %%
df[df.IncomeGroup == 'Low-income']
# Out:
#                         Country Name Country Code  Birthrate  Internet_Users  \
# 4                       Burkina Faso          BFA       35.1            15.0
# 5                            Burundi          BDI       34.5            10.0
# 7           Central African Republic          CAF       34.5             5.0
# 8                               Chad          TCD       36.0            10.0
# 10  Democratic Republic of the Congo          COD       40.0            10.0
# 13                           Eritrea         ERIT       24.6            15.0
# 15                          Ethiopia          ETH       30.2            25.0
# 20                     Guinea-Bissau          GNB       32.9            20.0
# 24                           Liberia          LBR       30.0            30.0
# 26                        Madagascar          MDG       28.3            15.0
# 27                            Malawi          MWI       38.6            15.0
# ...
